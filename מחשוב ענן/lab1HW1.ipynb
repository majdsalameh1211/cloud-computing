# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Step 2: Create and write to the file
# Define the path in Google Drive where you want to create the file
file_path = '/content/drive/My Drive/Students.txt'

# Create and write to the file
with open(file_path, 'w') as file:
    file.write("Name : Mohamad Abu Ahmad  Email : Mohammad.abu.ahmad@e.braude.ac.il \nName : Shady Mansour Email : Shady.Mansour@e.braude.ac.il")

print(f"File created and written to at: {file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# File created and written to at: /content/drive/My Drive/Students.txt
